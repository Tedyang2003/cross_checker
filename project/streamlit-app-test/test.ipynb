# %%
import pandas as pd

pd.read_csv("test.csv")
# Out:
#     Unnamed: 0                                              Chunk  \
# 0            0         Chunk 1: Fire at Dryden Textiles facility.
# 1            1         Chunk 1: Fire at Dryden Textiles facility.
# 2            2         Chunk 1: Fire at Dryden Textiles facility.
# 3            3               Chunk 2: Fire at industrial building
# 4            4               Chunk 2: Fire at industrial building
# 5            5               Chunk 2: Fire at industrial building
# 6            6               Chunk 2: Fire at industrial building
# 7            7               Chunk 2: Fire at industrial building
# 8            8       Chunk 3: Fire incident and company response.
# 9            9       Chunk 3: Fire incident and company response.
# 10          10       Chunk 3: Fire incident and company response.
# 11          11       Chunk 3: Fire incident and company response.
# 12          12  Chunk 4: Textile manufacturing safety violations.
# ...
