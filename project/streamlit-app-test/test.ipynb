# %%
import pandas as pd

pd.read_csv("test.csv")
# Out:
#       Chunk                                         Chunk Text  \
# 0   Chunk 1  A fire broke out late Monday night at the Dryd...
# 1   Chunk 1  A fire broke out late Monday night at the Dryd...
# 2   Chunk 1  A fire broke out late Monday night at the Dryd...
# 3   Chunk 1  A fire broke out late Monday night at the Dryd...
# 4   Chunk 1  A fire broke out late Monday night at the Dryd...
# 5   Chunk 2  No fatalities were reported, but two workers r...
# 6   Chunk 2  No fatalities were reported, but two workers r...
# 7   Chunk 2  No fatalities were reported, but two workers r...
# 8   Chunk 2  No fatalities were reported, but two workers r...
# 9   Chunk 2  No fatalities were reported, but two workers r...
# 10  Chunk 3  The company did not respond to requests for fu...
# 11  Chunk 3  The company did not respond to requests for fu...
# 12  Chunk 3  The company did not respond to requests for fu...
# 13  Chunk 3  The company did not respond to requests for fu...
# ...
